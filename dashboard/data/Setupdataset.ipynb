# %% [markdown]
# ## Human Resources Department Prject
#
# In this notebook we are going to make the data ready to be used to create dashboard.

# %%
DF_PATH = '../../data/processed/HR_Processed.csv'

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Read dataset

# %%
df = pd.read_csv(DF_PATH)
df.sample(3)
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 1354   56       Yes  Travel_Rarely       1162  Research & Development
# 237    52        No     Non-Travel        771                   Sales
# 756    32        No     Non-Travel       1109  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 1354                24          2  Life Sciences                        1
# 237                  2          4  Life Sciences                        1
# 756                 29          4        Medical                        4
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 1354    Male  ...                  3                         4
# 237     Male  ...                  3                         4
# 756   Female  ...                  3                         2
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 1354                 0                 5                      3
# 237                  0                33                      2
# 756                  0                10                      2
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 1354               3               4                   2
# 237                4              33                   7
# 756                3               8                   7
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 1354                        1                    0
# 237                        15                   12
# 756                         7                    7
#
# [3 rows x 31 columns]

# %% [markdown]
# #### Map categorical columns number to a category

# %%
df['Education'] = df['Education'].map({1: 'Below College', 2: 'College', 3: 'Bachelor', 4: 'Master', 5: 'Doctor'})
df['EnvironmentSatisfaction'] = df['EnvironmentSatisfaction'].map({1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'})
df['JobInvolvement'] = df['JobInvolvement'].map({1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'})
df['JobSatisfaction'] = df['JobSatisfaction'].map({1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'})
df['PerformanceRating'] = df['PerformanceRating'].map({1: 'Low', 2: 'Good', 3: 'Excellent', 4: 'Outstanding'})
df['RelationshipSatisfaction'] = df['RelationshipSatisfaction'].map({1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'})
df['WorkLifeBalance'] = df['WorkLifeBalance'].map({1: 'Bad', 2: 'Good', 3: 'Better', 4: 'Best'})

# %%
df.sample(3)
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 242    41        No  Travel_Rarely       1411  Research & Development
# 103    34        No  Travel_Rarely        665  Research & Development
# 1218   41        No  Travel_Rarely        918                   Sales
#
#       DistanceFromHome Education EducationField EnvironmentSatisfaction  \
# 242                 19   College  Life Sciences                    High
# 103                  6    Master          Other                     Low
# 1218                 6  Bachelor      Marketing               Very High
#
#       Gender  ...  PerformanceRating RelationshipSatisfaction  \
# 242     Male  ...          Excellent                      Low
# 103   Female  ...          Excellent                     High
# 1218    Male  ...          Excellent                   Medium
#
#       StockOptionLevel TotalWorkingYears TrainingTimesLastYear  \
# 242                  2                17                     2
# 103                  0                16                     3
# 1218                 0                10                     3
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 242             Good               1                   0
# 103           Better              16                  13
# 1218          Better              10                   8
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 242                         0                    0
# 103                         2                   10
# 1218                        8                    7
#
# [3 rows x 31 columns]

# %% [markdown]
# #### Save dataset

# %%
df.to_csv('HR_Dashboard_Data.csv', index=False)
